# %% [markdown]
# # Dathaton FIAP - PASSOS MÁGICOS

# %% [markdown]
# ## Importing Libraries

# %%
from dotenv import load_dotenv

import os
from pathlib import Path

import pandas as pd

from pycaret.classification import setup, compare_models, predict_model, tune_model, finalize_model, plot_model, evaluate_model, save_model, load_model

import psycopg2 as ps

# %% [markdown]
# ## Loading Data

# %%
load_dotenv()

DB_KEY = os.getenv("DB_KEY")
DB_NAME = os.getenv("DB_NAME")

# %%
conn = ps.connect(
    dbname='PEDE_PASSOS',
    user=DB_NAME,
    host='localhost',
    port='5432',
    password=DB_KEY)

# %%
data = pd.read_sql("SELECT * FROM pede_passos.students_avaliation", con=conn, )

# %%
# path = Path('../data/raw/PEDE_PASSOS_DATASET_FIAP.csv')

# data = pd.read_csv(path, sep=';')

# %% [markdown]
# ## Data Wrangling

# %%
melt_data = data.melt(id_vars=['NOME'], var_name='feature', value_name='value')
melt_data.rename(columns={'NOME': 'name'}, inplace=True)
melt_data['feature'] = melt_data['feature'].astype(str)
melt_data[['feature', 'year']] = melt_data['feature'].str.rsplit('_', n=1, expand=True)

# %%
fase = melt_data

# %%
fase['feature'] = fase['feature'].str.replace('FASE_TURMA', 'FASE')
fase = fase[fase['feature']=='FASE']
fase.loc[fase['year'] == '2020', 'value'] = fase.loc[fase['year'] == '2020', 'value'].str[:-1]

# %%
fase.dropna(inplace=True, axis=0, how='any')
fase['value'] = pd.to_numeric(fase['value'], errors='coerce')
fase.dropna(subset=['value'], inplace=True)

scholars = fase[fase['value'] <= 7]
academics = fase[fase['value'] > 7]

# %%
fase[(fase['year'] != '2020') & fase['value'] < 7]
# Out:
#              name feature  value  year
# 4047      ALUNO-1    FASE    2.0  2020
# 4049      ALUNO-3    FASE    3.0  2020
# 4050      ALUNO-4    FASE    1.0  2020
# 4051      ALUNO-5    FASE    2.0  2020
# 4054      ALUNO-8    FASE    4.0  2020
# ...           ...     ...    ...   ...
# 52603  ALUNO-1342    FASE    2.0  2022
# 52604  ALUNO-1343    FASE    2.0  2022
# 52607  ALUNO-1346    FASE    0.0  2022
# 52609  ALUNO-1348    FASE    4.0  2022
# 52610  ALUNO-1349    FASE    3.0  2022
#
# [2275 rows x 4 columns]

# %%
scholars
# Out:
#              name feature  value  year
# 4047      ALUNO-1    FASE    2.0  2020
# 4049      ALUNO-3    FASE    3.0  2020
# 4050      ALUNO-4    FASE    1.0  2020
# 4051      ALUNO-5    FASE    2.0  2020
# 4054      ALUNO-8    FASE    4.0  2020
# ...           ...     ...    ...   ...
# 52603  ALUNO-1342    FASE    2.0  2022
# 52604  ALUNO-1343    FASE    2.0  2022
# 52607  ALUNO-1346    FASE    0.0  2022
# 52609  ALUNO-1348    FASE    4.0  2022
# 52610  ALUNO-1349    FASE    3.0  2022
#
# [2251 rows x 4 columns]

# %%
melt_data['id'] = melt_data['name'] + '_' + melt_data['year']
melt_data.set_index('id', inplace=True)

melt_data.drop(columns=['name', 'year'], inplace=True)

# %%
values_to_keep = ['IAA', 'IEG', 'IPS', 'IDA', 'IPP','IPV', 'IAN', 'PEDRA']

melt_data = melt_data[melt_data['feature'].isin(values_to_keep)]

melt_data = melt_data.pivot(columns='feature', values='value')
melt_data.columns.name = None

# %%
scholars_to_keep = scholars['name'] + '_' + scholars['year']
scholars_data = melt_data.loc[melt_data.index.isin(scholars_to_keep)]

academics_to_keep = academics['name'] + '_' + academics['year']
academics_data = melt_data.loc[melt_data.index.isin(academics_to_keep)]

# %%
scholars_data
# Out:
#                                IAA   IAN                IDA  \
# id
# ALUNO-1000_2022            9.50002  10.0                2.0
# ALUNO-1001_2021                9.5  10.0                6.9
# ALUNO-1001_2022  9.000020000000001   5.0  8.083333333333334
# ALUNO-1002_2020            9.16668     5  8.333333333333334
# ALUNO-1002_2021                8.8   5.0                7.5
# ...                            ...   ...                ...
# ALUNO-998_2022             9.50002  10.0  6.166666666666666
# ALUNO-999_2020             8.33334    10  7.333333333333333
# ALUNO-999_2021                 7.9  10.0                6.4
# ALUNO-99_2022              8.75001   5.0               7.25
# ALUNO-9_2022     9.000020000000001  10.0  2.133333333333333
#
#                                IEG                IPP    IPS  \
# id
# ALUNO-1000_2022  8.093434343434343  6.458333333333334    7.5
# ALUNO-1001_2021               10.0                8.4    7.5
# ALUNO-1001_2022  8.452380952380953              5.625  5.625
# ALUNO-1002_2020                9.4              8.125    7.5
# ALUNO-1002_2021                8.3                7.7    7.5
# ...                            ...                ...    ...
# ALUNO-998_2022   9.668209876543209              5.625  5.625
# ALUNO-999_2020                 5.8              6.875  3.125
# ALUNO-999_2021                 6.1                6.9    4.4
# ALUNO-99_2022                 10.0                7.5    7.5
# ALUNO-9_2022     6.820377689942907               3.75    5.0
#
#                                IPV     PEDRA
# id
# ALUNO-1000_2022  6.611106666666666     Ágata
# ALUNO-1001_2021               10.0   Topázio
# ALUNO-1001_2022               7.75  Ametista
# ALUNO-1002_2020  7.944446666666668  Ametista
# ALUNO-1002_2021                8.1  Ametista
# ...                            ...       ...
# ALUNO-998_2022            7.499995  Ametista
# ALUNO-999_2020             7.72222     Ágata
# ALUNO-999_2021                 7.2     Ágata
# ALUNO-99_2022            7.2916625  Ametista
# ALUNO-9_2022               5.50001   Quartzo
#
# [2251 rows x 8 columns]

# %%
scholars_data.dropna(axis=0, subset='PEDRA', inplace=True)

pedras = ['Ágata', 'Topázio', 'Ametista', 'Quartzo']

scholars_data = scholars_data[melt_data['PEDRA'].isin(pedras)]

# %%
for col in scholars_data.columns:
	if col != 'PEDRA':
		scholars_data[col] = pd.to_numeric(scholars_data[col], errors='coerce')
scholars_data = scholars_data.dropna()

# %%
target = {'Quartzo': 0, 'Ágata': 1, 'Ametista': 2, 'Topázio': 3}

scholars_data['PEDRA'] = scholars_data['PEDRA'].map(target)

# %% [markdown]
# ## Data Modeling

# %%
# Configurar o ambiente de PyCaret
clf = setup(data=scholars_data, target='PEDRA', session_id=123, experiment_name='pedra_prediction')

# Comparar todos os modelos disponíveis e selecionar o melhor
best_model = compare_models()

# Afinar o melhor modelo
tuned_model = tune_model(best_model)

# Finalizar o modelo
final_model = finalize_model(tuned_model)
# Out:
# <style type="text/css">
# #T_b57ed_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b57ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b57ed_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b57ed_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b57ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b57ed_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b57ed_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b57ed_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b57ed_row1_col1" class="data row1 col1" >PEDRA</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b57ed_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b57ed_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b57ed_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b57ed_row3_col1" class="data row3 col1" >(2249, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b57ed_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b57ed_row4_col1" class="data row4 col1" >(2249, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b57ed_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b57ed_row5_col1" class="data row5 col1" >(1574, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b57ed_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b57ed_row6_col1" class="data row6 col1" >(675, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b57ed_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b57ed_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b57ed_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b57ed_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b57ed_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b57ed_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b57ed_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b57ed_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b57ed_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b57ed_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b57ed_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b57ed_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b57ed_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b57ed_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b57ed_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b57ed_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b57ed_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b57ed_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b57ed_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b57ed_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b57ed_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b57ed_row17_col1" class="data row17 col1" >pedra_prediction</td>
#     </tr>
#     <tr>
#       <th id="T_b57ed_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b57ed_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b57ed_row18_col1" class="data row18 col1" >b415</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f27c0 th {
#   text-align: left;
# }
# #T_f27c0_row0_col0, #T_f27c0_row0_col2, #T_f27c0_row1_col0, #T_f27c0_row1_col1, #T_f27c0_row1_col2, #T_f27c0_row1_col3, #T_f27c0_row1_col4, #T_f27c0_row1_col5, #T_f27c0_row1_col6, #T_f27c0_row1_col7, #T_f27c0_row2_col0, #T_f27c0_row2_col1, #T_f27c0_row2_col3, #T_f27c0_row2_col4, #T_f27c0_row2_col5, #T_f27c0_row2_col6, #T_f27c0_row2_col7, #T_f27c0_row3_col0, #T_f27c0_row3_col1, #T_f27c0_row3_col2, #T_f27c0_row3_col3, #T_f27c0_row3_col4, #T_f27c0_row3_col5, #T_f27c0_row3_col6, #T_f27c0_row3_col7, #T_f27c0_row4_col0, #T_f27c0_row4_col1, #T_f27c0_row4_col2, #T_f27c0_row4_col3, #T_f27c0_row4_col4, #T_f27c0_row4_col5, #T_f27c0_row4_col6, #T_f27c0_row4_col7, #T_f27c0_row5_col0, #T_f27c0_row5_col1, #T_f27c0_row5_col2, #T_f27c0_row5_col3, #T_f27c0_row5_col4, #T_f27c0_row5_col5, #T_f27c0_row5_col6, #T_f27c0_row5_col7, #T_f27c0_row6_col0, #T_f27c0_row6_col1, #T_f27c0_row6_col2, #T_f27c0_row6_col3, #T_f27c0_row6_col4, #T_f27c0_row6_col5, #T_f27c0_row6_col6, #T_f27c0_row6_col7, #T_f27c0_row7_col0, #T_f27c0_row7_col1, #T_f27c0_row7_col2, #T_f27c0_row7_col3, #T_f27c0_row7_col4, #T_f27c0_row7_col5, #T_f27c0_row7_col6, #T_f27c0_row7_col7, #T_f27c0_row8_col0, #T_f27c0_row8_col1, #T_f27c0_row8_col2, #T_f27c0_row8_col3, #T_f27c0_row8_col4, #T_f27c0_row8_col5, #T_f27c0_row8_col6, #T_f27c0_row8_col7, #T_f27c0_row9_col0, #T_f27c0_row9_col1, #T_f27c0_row9_col2, #T_f27c0_row9_col3, #T_f27c0_row9_col4, #T_f27c0_row9_col5, #T_f27c0_row9_col6, #T_f27c0_row9_col7, #T_f27c0_row10_col0, #T_f27c0_row10_col1, #T_f27c0_row10_col2, #T_f27c0_row10_col3, #T_f27c0_row10_col4, #T_f27c0_row10_col5, #T_f27c0_row10_col6, #T_f27c0_row10_col7, #T_f27c0_row11_col0, #T_f27c0_row11_col1, #T_f27c0_row11_col2, #T_f27c0_row11_col3, #T_f27c0_row11_col4, #T_f27c0_row11_col5, #T_f27c0_row11_col6, #T_f27c0_row11_col7, #T_f27c0_row12_col0, #T_f27c0_row12_col1, #T_f27c0_row12_col2, #T_f27c0_row12_col3, #T_f27c0_row12_col4, #T_f27c0_row12_col5, #T_f27c0_row12_col6, #T_f27c0_row12_col7, #T_f27c0_row13_col0, #T_f27c0_row13_col1, #T_f27c0_row13_col2, #T_f27c0_row13_col3, #T_f27c0_row13_col4, #T_f27c0_row13_col5, #T_f27c0_row13_col6, #T_f27c0_row13_col7 {
#   text-align: left;
# }
# #T_f27c0_row0_col1, #T_f27c0_row0_col3, #T_f27c0_row0_col4, #T_f27c0_row0_col5, #T_f27c0_row0_col6, #T_f27c0_row0_col7, #T_f27c0_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f27c0_row0_col8, #T_f27c0_row2_col8, #T_f27c0_row3_col8, #T_f27c0_row4_col8, #T_f27c0_row5_col8, #T_f27c0_row6_col8, #T_f27c0_row7_col8, #T_f27c0_row8_col8, #T_f27c0_row9_col8, #T_f27c0_row10_col8, #T_f27c0_row11_col8, #T_f27c0_row12_col8, #T_f27c0_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f27c0_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f27c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f27c0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f27c0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f27c0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f27c0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f27c0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f27c0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f27c0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f27c0_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f27c0_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f27c0_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_f27c0_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_f27c0_row0_col1" class="data row0 col1" >0.8856</td>
#       <td id="T_f27c0_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_f27c0_row0_col3" class="data row0 col3" >0.8856</td>
#       <td id="T_f27c0_row0_col4" class="data row0 col4" >0.8871</td>
#       <td id="T_f27c0_row0_col5" class="data row0 col5" >0.8853</td>
#       <td id="T_f27c0_row0_col6" class="data row0 col6" >0.8355</td>
#       <td id="T_f27c0_row0_col7" class="data row0 col7" >0.8362</td>
#       <td id="T_f27c0_row0_col8" class="data row0 col8" >0.3480</td>
#     </tr>
#     <tr>
#       <th id="T_f27c0_level0_row1" class="row_heading level0 row1" >qda</th>
#       <td id="T_f27c0_row1_col0" class="data row1 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_f27c0_row1_col1" class="data row1 col1" >0.8627</td>
#       <td id="T_f27c0_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_f27c0_row1_col3" class="data row1 col3" >0.8627</td>
#       <td id="T_f27c0_row1_col4" class="data row1 col4" >0.8643</td>
#       <td id="T_f27c0_row1_col5" class="data row1 col5" >0.8619</td>
#       <td id="T_f27c0_row1_col6" class="data row1 col6" >0.8017</td>
#       <td id="T_f27c0_row1_col7" class="data row1 col7" >0.8029</td>
#       <td id="T_f27c0_row1_col8" class="data row1 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_f27c0_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_f27c0_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_f27c0_row2_col1" class="data row2 col1" >0.8609</td>
#       <td id="T_f27c0_row2_col2" class="data row2 col2" >0.9765</td>
#       <td id="T_f27c0_row2_col3" class="data row2 col3" >0.8609</td>
#       <td id="T_f27c0_row2_col4" class="data row2 col4" >0.8638</td>
#       <td id="T_f27c0_row2_col5" class="data row2 col5" >0.8598</td>
#       <td id="T_f27c0_row2_col6" class="data row2 col6" >0.7982</td>
#       <td id="T_f27c0_row2_col7" class="data row2 col7" >0.7998</td>
#       <td id="T_f27c0_row2_col8" class="data row2 col8" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_f27c0_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_f27c0_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f27c0_row3_col1" class="data row3 col1" >0.8602</td>
#       <td id="T_f27c0_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_f27c0_row3_col3" class="data row3 col3" >0.8602</td>
#       <td id="T_f27c0_row3_col4" class="data row3 col4" >0.8652</td>
#       <td id="T_f27c0_row3_col5" class="data row3 col5" >0.8582</td>
#       <td id="T_f27c0_row3_col6" class="data row3 col6" >0.7963</td>
#       <td id="T_f27c0_row3_col7" class="data row3 col7" >0.7988</td>
#       <td id="T_f27c0_row3_col8" class="data row3 col8" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_f27c0_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_f27c0_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f27c0_row4_col1" class="data row4 col1" >0.8539</td>
#       <td id="T_f27c0_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_f27c0_row4_col3" class="data row4 col3" >0.8539</td>
#       <td id="T_f27c0_row4_col4" class="data row4 col4" >0.8567</td>
#       <td id="T_f27c0_row4_col5" class="data row4 col5" >0.8527</td>
#       <td id="T_f27c0_row4_col6" class="data row4 col6" >0.7882</td>
#       <td id="T_f27c0_row4_col7" class="data row4 col7" >0.7897</td>
#       <td id="T_f27c0_row4_col8" class="data row4 col8" >0.1560</td>
#     </tr>
#     <tr>
#       <th id="T_f27c0_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_f27c0_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f27c0_row5_col1" class="data row5 col1" >0.8533</td>
#       <td id="T_f27c0_row5_col2" class="data row5 col2" >0.9708</td>
#       <td id="T_f27c0_row5_col3" class="data row5 col3" >0.8533</td>
#       <td id="T_f27c0_row5_col4" class="data row5 col4" >0.8566</td>
#       <td id="T_f27c0_row5_col5" class="data row5 col5" >0.8527</td>
#       <td id="T_f27c0_row5_col6" class="data row5 col6" >0.7885</td>
#       <td id="T_f27c0_row5_col7" class="data row5 col7" >0.
# <style type="text/css">
# #T_6874c_row10_col0, #T_6874c_row10_col1, #T_6874c_row10_col2, #T_6874c_row10_col3, #T_6874c_row10_col4, #T_6874c_row10_col5, #T_6874c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6874c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6874c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6874c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6874c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6874c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6874c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6874c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6874c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6874c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6874c_row0_col0" class="data row0 col0" >0.8734</td>
#       <td id="T_6874c_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_6874c_row0_col2" class="data row0 col2" >0.8734</td>
#       <td id="T_6874c_row0_col3" class="data row0 col3" >0.8754</td>
#       <td id="T_6874c_row0_col4" class="data row0 col4" >0.8737</td>
#       <td id="T_6874c_row0_col5" class="data row0 col5" >0.8201</td>
#       <td id="T_6874c_row0_col6" class="data row0 col6" >0.8205</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6874c_row1_col0" class="data row1 col0" >0.9177</td>
#       <td id="T_6874c_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_6874c_row1_col2" class="data row1 col2" >0.9177</td>
#       <td id="T_6874c_row1_col3" class="data row1 col3" >0.9192</td>
#       <td id="T_6874c_row1_col4" class="data row1 col4" >0.9171</td>
#       <td id="T_6874c_row1_col5" class="data row1 col5" >0.8816</td>
#       <td id="T_6874c_row1_col6" class="data row1 col6" >0.8824</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6874c_row2_col0" class="data row2 col0" >0.9177</td>
#       <td id="T_6874c_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_6874c_row2_col2" class="data row2 col2" >0.9177</td>
#       <td id="T_6874c_row2_col3" class="data row2 col3" >0.9180</td>
#       <td id="T_6874c_row2_col4" class="data row2 col4" >0.9177</td>
#       <td id="T_6874c_row2_col5" class="data row2 col5" >0.8828</td>
#       <td id="T_6874c_row2_col6" class="data row2 col6" >0.8829</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6874c_row3_col0" class="data row3 col0" >0.8987</td>
#       <td id="T_6874c_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_6874c_row3_col2" class="data row3 col2" >0.8987</td>
#       <td id="T_6874c_row3_col3" class="data row3 col3" >0.8988</td>
#       <td id="T_6874c_row3_col4" class="data row3 col4" >0.8986</td>
#       <td id="T_6874c_row3_col5" class="data row3 col5" >0.8547</td>
#       <td id="T_6874c_row3_col6" class="data row3 col6" >0.8548</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6874c_row4_col0" class="data row4 col0" >0.8662</td>
#       <td id="T_6874c_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_6874c_row4_col2" class="data row4 col2" >0.8662</td>
#       <td id="T_6874c_row4_col3" class="data row4 col3" >0.8654</td>
#       <td id="T_6874c_row4_col4" class="data row4 col4" >0.8643</td>
#       <td id="T_6874c_row4_col5" class="data row4 col5" >0.8059</td>
#       <td id="T_6874c_row4_col6" class="data row4 col6" >0.8067</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6874c_row5_col0" class="data row5 col0" >0.8726</td>
#       <td id="T_6874c_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_6874c_row5_col2" class="data row5 col2" >0.8726</td>
#       <td id="T_6874c_row5_col3" class="data row5 col3" >0.8769</td>
#       <td id="T_6874c_row5_col4" class="data row5 col4" >0.8734</td>
#       <td id="T_6874c_row5_col5" class="data row5 col5" >0.8179</td>
#       <td id="T_6874c_row5_col6" class="data row5 col6" >0.8190</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6874c_row6_col0" class="data row6 col0" >0.8917</td>
#       <td id="T_6874c_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_6874c_row6_col2" class="data row6 col2" >0.8917</td>
#       <td id="T_6874c_row6_col3" class="data row6 col3" >0.8916</td>
#       <td id="T_6874c_row6_col4" class="data row6 col4" >0.8912</td>
#       <td id="T_6874c_row6_col5" class="data row6 col5" >0.8432</td>
#       <td id="T_6874c_row6_col6" class="data row6 col6" >0.8436</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6874c_row7_col0" class="data row7 col0" >0.8917</td>
#       <td id="T_6874c_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_6874c_row7_col2" class="data row7 col2" >0.8917</td>
#       <td id="T_6874c_row7_col3" class="data row7 col3" >0.8927</td>
#       <td id="T_6874c_row7_col4" class="data row7 col4" >0.8914</td>
#       <td id="T_6874c_row7_col5" class="data row7 col5" >0.8445</td>
#       <td id="T_6874c_row7_col6" class="data row7 col6" >0.8450</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6874c_row8_col0" class="data row8 col0" >0.8599</td>
#       <td id="T_6874c_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_6874c_row8_col2" class="data row8 col2" >0.8599</td>
#       <td id="T_6874c_row8_col3" class="data row8 col3" >0.8635</td>
#       <td id="T_6874c_row8_col4" class="data row8 col4" >0.8606</td>
#       <td id="T_6874c_row8_col5" class="data row8 col5" >0.8011</td>
#       <td id="T_6874c_row8_col6" class="data row8 col6" >0.8019</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6874c_row9_col0" class="data row9 col0" >0.8662</td>
#       <td id="T_6874c_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_6874c_row9_col2" class="data row9 col2" >0.8662</td>
#       <td id="T_6874c_row9_col3" class="data row9 col3" >0.8706</td>
#       <td id="T_6874c_row9_col4" class="data row9 col4" >0.8656</td>
#       <td id="T_6874c_row9_col5" class="data row9 col5" >0.8050</td>
#       <td id="T_6874c_row9_col6" class="data row9 col6" >0.8067</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6874c_row10_col0" class="data row10 col0" >0.8856</td>
#       <td id="T_6874c_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_6874c_row10_col2" class="data row10 col2" >0.8856</td>
#       <td id="T_6874c_row10_col3" class="data row10 col3" >0.8872</td>
#       <td id="T_6874c_row10_col4" class="data row10 col4" >0.8854</td>
#       <td id="T_6874c_row10_col5" class="data row10 col5" >0.8357</td>
#       <td id="T_6874c_row10_col6" class="data row10 col6" >0.8363</td>
#     </tr>
#     <tr>
#       <th id="T_6874c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6874c_row11_col0" class="data row11 col0" >0.0201</td>
#       <td id="T_6874c_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_6874c_row11_col2" class="data row11 col2" >0.0201</td>
#       <td id="T_6874c_row11_col3" class="data row11 col3" >0.0193</td>
#       <td id="T_6874c_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ## Evaluation

# %%
# Avaliar o modelo final
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Salvar o modelo
save_model(final_model, '../models/lr_pedra_classification')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['IAA', 'IAN', 'IDA', 'IEG', 'IPP',
#                                               'IPS', 'IPV'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, include=[...
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('actual_estimator',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=123,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  '../models/lr_pedra_classification.pkl')
